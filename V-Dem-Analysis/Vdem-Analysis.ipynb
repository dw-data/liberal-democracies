# %%
# importing the necessary libraries
import pandas as pd
import altair as alt
import numpy as np

# %%
#reading in the dataset
df = pd.read_csv('../data/data_raw/V-Dem-CY-Core_csv_v13/V-Dem-CY-Core-v13.csv')
df.head()
# Out:
#   country_name country_text_id  country_id  year historical_date  project  \
# 0       Mexico             MEX           3  1789      1789-12-31        1
# 1       Mexico             MEX           3  1790      1790-12-31        1
# 2       Mexico             MEX           3  1791      1791-12-31        1
# 3       Mexico             MEX           3  1792      1792-12-31        1
# 4       Mexico             MEX           3  1793      1793-12-31        1
#
#    historical                  histname  codingstart  codingend  ...  \
# 0           1  Viceroyalty of New Spain         1789       2022  ...
# 1           1  Viceroyalty of New Spain         1789       2022  ...
# 2           1  Viceroyalty of New Spain         1789       2022  ...
# 3           1  Viceroyalty of New Spain         1789       2022  ...
# 4           1  Viceroyalty of New Spain         1789       2022  ...
#
#    v2xme_altinf_sd  v2xps_party  v2xps_party_codelow  v2xps_party_codehigh  \
# 0             0.67          NaN                  NaN                   NaN
# 1             0.67          NaN                  NaN                   NaN
# 2             0.67          NaN                  NaN                   NaN
# 3             0.67          NaN                  NaN                   NaN
# 4             0.67          NaN                  NaN                   NaN
#
#    v2x_divparctrl  v2x_feduni  v2xca_academ  v2xca_academ_codelow  \
# 0             NaN         0.0           NaN                   NaN
# 1             NaN         0.0           NaN                   NaN
# 2             NaN         0.0           NaN                   NaN
# 3             NaN         0.0           NaN                   NaN
# 4             NaN         0.0           NaN                   NaN
#
#    v2xca_academ_codehigh  v2xca_academ_sd
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
#
# [5 rows x 1818 columns]

# %%
#reducing dataframe to only include data points from 2000 and later
dfr=df[df['year']>=2000]
dfr.head()
# Out:
#     country_name country_text_id  country_id  year historical_date  project  \
# 211       Mexico             MEX           3  2000      2000-12-31        0
# 212       Mexico             MEX           3  2001      2001-12-31        0
# 213       Mexico             MEX           3  2002      2002-12-31        0
# 214       Mexico             MEX           3  2003      2003-12-31        0
# 215       Mexico             MEX           3  2004      2004-12-31        0
#
#      historical               histname  codingstart  codingend  ...  \
# 211           1  United Mexican States         1789       2022  ...
# 212           1  United Mexican States         1789       2022  ...
# 213           1  United Mexican States         1789       2022  ...
# 214           1  United Mexican States         1789       2022  ...
# 215           1  United Mexican States         1789       2022  ...
#
#      v2xme_altinf_sd  v2xps_party  v2xps_party_codelow  v2xps_party_codehigh  \
# 211            0.638        0.919                0.842                  0.96
# 212            0.638        0.919                0.842                  0.96
# 213            0.647        0.919                0.842                  0.96
# 214            0.647        0.919                0.842                  0.96
# 215            0.647        0.919                0.842                  0.96
#
#      v2x_divparctrl  v2x_feduni  v2xca_academ  v2xca_academ_codelow  \
# 211          -1.575       0.986         0.897                 0.837
# 212          -1.575       0.986         0.925                 0.877
# 213          -1.575       0.986         0.935                 0.885
# 214          -1.575       0.986         0.935                 0.885
# 215          -1.575       0.986         0.927                 0.875
#
#      v2xca_academ_codehigh  v2xca_academ_sd
# 211                  0.944            0.620
# 212                  0.962            0.622
# 213                  0.967            0.627
# 214                  0.967            0.627
# 215                  0.961            0.621
#
# [5 rows x 1818 columns]

# %%
# displaying a list of all columns in the dataset and their data types
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 1818 columns):
#  #     Column                           Non-Null Count  Dtype
# ---    ------                           --------------  -----
#  0     country_name                     27555 non-null  object
#  1     country_text_id                  27555 non-null  object
#  2     country_id                       27555 non-null  int64
#  3     year                             27555 non-null  int64
#  4     historical_date                  27555 non-null  object
#  5     project                          27555 non-null  int64
#  6     historical                       27555 non-null  int64
#  7     histname                         27453 non-null  object
#  8     codingstart                      27555 non-null  int64
#  9     codingend                        27555 non-null  int64
#  10    codingstart_contemp              26156 non-null  float64
#  11    codingend_contemp                26156 non-null  float64
#  12    codingstart_hist                 16825 non-null  float64
#  13    codingend_hist                   16825 non-null  float64
#  14    gapstart1                        3770 non-null   float64
#  15    gapstart2                        317 non-null    float64
#  16    gapstart3                        168 non-null    float64
#  17    gapend1                          3770 non-null   float64
#  18    gapend2                          317 non-null    float64
#  19    gapend3                          168 non-null    float64
#  20    gap_index                        27555 non-null  int64
#  21    COWcode                          26720 non-null  float64
#  22    v2x_polyarchy                    26273 non-null  float64
#  23    v2x_polyarchy_codelow            26273 non-null  float64
#  24    v2x_polyarchy_codehigh           26273 non-null  float64
#  25    v2x_polyarchy_sd                 26273 non-null  float64
#  26    v2x_libdem                       25134 non-null  float64
#  27    v2x_libdem_codelow               25134 non-null  float64
#  28    v2x_libdem_codehigh              25134 non-null  float64
#  29    v2x_libdem_sd                    25134 non-null  float64
#  30    v2x_partipdem                    25661 non-null  float64
#  31    v2x_partipdem_codelow            25661 non-null  float64
#  32    v2x_partipdem_codehigh           25661 non-null  float64
#  33    v2x_partipdem_sd                 25661 non-null  float64
#  34    v2x_delibdem                     19129 non-null  float64
#  35    v2x_delibdem_codelow             19129 non-null  float64
#  36    v2x_delibdem_codehigh            19129 non-null  float64
#  37    v2x_delibdem_sd                  19129 non-null  float64
#  38    v2x_egaldem                      19130 non-null  float64
#  39    v2x_egaldem_codelow              19130 non-null  float64
#  40    v2x_egaldem_codehigh             19130 non-null  float64
#  41    v2x_egaldem_sd                   19130 non-null  float64
#  42    v2x_api                          26273 non-null  float64
#  43    v2x_api_codelow                  26273 non-null  float64
#  44    v2x_api_codehigh                 26273 non-null  float64
#  45    v2x_api_sd                       26273 non-null  float64
#  46    v2x_mpi                          26273 non-null  float64
#  47    v2x_mpi_codelow                  26273 non-null  float64
#  48    v2x_mpi_codehigh                 26273 non-null  float64
#  49    v2x_mpi_sd                       26273 non-null  float64
#  50    v2x_freexp_altinf                27019 non-null  float64
#  51    v2x_freexp_altinf_codelow        27019 non-null  float64
#  52    v2x_freexp_altinf_codehigh       27019 non-null  float64
#  53    v2x_freexp_altinf_sd             27019 non-null  float64
#  54    v2x_frassoc_thick                26882 non-null  float64
#  55    v2x_frassoc_thick_codelow        26882 non-null  float64
#  56    v2x_frassoc_thick_codehigh       26882 non-null  float64
#  57    v2x_frassoc_thick_sd             26882 non-null  float64
#  58    v2x_suffr                        27245 non-null  float64
#  59    v2xel_frefair                    27433 non-null  float64
#  60    v2xel_frefair_codelow            27433 non-null  float64
#  61    v2xel_frefair_codehigh           27433 non-null  float64
#  62    v2xel_frefair_sd                 27433 non-null  float64
#  63    v2x_elecoff                      26854 non-null  float64
#  64    v2x_liberal                      25906 non-null  float64
#  65    v2x_liberal_codelow              25906 non-null  float64
#  66    v2x_liberal_codehigh             25906 non-null  float64
#  67    v2x_liberal_sd                   25906 non-null  float64
#  68    v2xcl_rol                        27437 non-null  float64
#  69    v2xcl_rol_codelow                27437 non-null  float64
#  70    v2xcl_rol_codehigh               27437 non-null  float64
#  71    v2xcl_rol_sd                     27437 non-null  float64
#  72    v2x_jucon                        25997 non-null  float64
#  73    v2x_jucon_codelow                25997 non-null  float64
#  74    v2x_jucon_codehigh               25997 non-null  float64
#  75    v2x_jucon_sd                     25997 non-null  float64
#  76    v2xlg_legcon                     21314 non-null  float64
#  77    v2xlg_legcon_codelow             21314 non-null  float64
#  78    v2xlg_legcon_codehigh            21314 non-null  float64
#  79    v2xlg_legcon_sd                  21314 non-null  float64
#  80    v2x_partip                       26408 non-null  float64
#  81    v2x_partip_codelow               26408 non-null  float64
#  82    v2x_partip_codehigh              26408 non-null  float64
#  83    v2x_partip_sd                    26408 non-null  float64
#  84    v2x_cspart                       26928 non-null  float64
#  85    v2x_cspart_codelow               26928 non-null  float64
#  86    v2x_cspart_codehigh              26928 non-null  float64
#  87    v2x_cspart_sd                    26928 non-null  float64
#  88    v2xdd_dd                         19189 non-null  float64
#  89    v2xel_locelec                    23366 non-null  float64
#  90    v2xel_locelec_codelow            23366 non-null  float64
#  91    v2xel_locelec_codehigh           23366 non-null  float64
#  92    v2xel_locelec_sd                 23366 non-null  float64
#  93    v2xel_regelec                    26269 non-null  float64
#  94    v2xel_regelec_codelow            26269 non-null  float64
#  95    v2xel_regelec_codehigh           26269 non-null  float64
#  96    v2xel_regelec_sd                 26269 non-null  float64
#  97    v2xdl_delib                      19189 non-null  float64
#  98    v2xdl_delib_codelow              19189 non-null  float64
#  99    v2xdl_delib_codehigh             19189 non-null  float64
#  100   v2xdl_delib_sd                   19189 non-null  float64
#  101   v2x_egal                         19190 non-null  float64
#  102   v2x_egal_codelow                 19190 non-null  float64
#  103   v2x_egal_codehigh                19190 non-null  float64
#  104   v2x_egal_sd                      19190 non-null  float64
#  105   v2xeg_eqprotec                   27362 non-null  float64
#  106   v2xeg_eqprotec_codelow           27362 non-null  float64
#  107   v2xeg_eqprotec_codehigh          27362 non-null  float64
#  108   v2xeg_eqprotec_sd                27362 non-null  float64
#  109   v2xeg_eqaccess                   27351 non-null  float64
#  110   v2xeg_eqaccess_codelow           27351 non-null  float64
#  111   v2xeg_eqaccess_codehigh          27351 non-null  float64
#  112   v2xeg_eqaccess_sd                27351 non-null  float64
#  113   v2xeg_eqdr                       19191 non-null  float64
#  114   v2xeg_eqdr_codelow               19191 non-null  float64
#  115   v2xeg_eqdr_codehigh              19191 non-null  float64
#  116   v2xeg_eqdr_sd                    19191 non-null  float64
#  117   v2eltype_0                       4939 non-null   float64
#  118   v2eltype_1                       4939 non-null   float64
#  119   v2eltype_4                       4939 non-null   float64
#  120   v2eltype_5                       4939 non-null   float64
#  121   v2eltype_6                       4939 non-null   float64
#  122   v2eltype_7                       4939 non-null   float64
#  123   v2elsuffrage                     27245 non-null  float64
#  124   v2elembaut                       25018 non-null  float64
#  125   v2elembaut_codelow               25018 non-null  float64
#  126   v2elembaut_codehigh              25018 non-null  float64
#  127   v2elembaut_sd                    25018 non-null  float64
#  128   v2elembaut_osp                   25018 non-null  float64
#  129   v2elembaut_osp_codelow           25018 non-null  float64
#  130   v2elembaut_osp_codehigh          25018 non-null  float64
#  131   v2elembaut_osp_sd                25018 non-null  float64
#  132   v2elembaut_ord                   25018 non-null  float64
#  133   v2elembaut_ord_codelow           25018 non-null  float64
#  134   v2elembaut_ord_codehigh          25018 non-null  float64
#  135   v2elembaut_mean                  25018 non-null  float64
#  136   v2elembaut_nr                    25018 non-null  float64
#  137   v2elembcap                       24867 non-null  float64
#  138   v2elembcap_codelow               24867 non-null  float64
#  139   v2elembcap_codehigh              24867 non-null  float64
#  140   v2elembcap_sd                    24867 non-null  float64
#  141   v2elembcap_osp                   24867 non-null  float64
#  142   v2elembcap_osp_codelow           24867 non-null  float64
#  143   v2elembcap_osp_codehigh          24867 non-null  float64
#  144   v2elembcap_osp_sd                24867 non-null  float64
#  145   v2elembcap_ord                   24867 non-null  float64
#  146   v2elembcap_ord_codelow           24867 non-null  float64
#  147   v2elembcap_ord_codehigh          24867 non-null  float64
#  148   v2elembcap_mean                  24867 non-null  float64
#  149   v2elembcap_nr                    24867 non-null  float64
#  150   v2elmulpar                       15499 non-null  float64
#  151   v2elmulpar_codelow               15499 non-null  float64
#  152   v2elmulpar_codehigh              15499 non-null  float64
#  153   v2elmulpar_sd                    15499 non-null  float64
#  154   v2elmulpar_osp                   15499 non-null  float64
#  155   v2elmulpar_osp_codelow           15499 non-null  float64
#  156   v2elmulpar_osp_codehigh          15499 non-null  float64
#  157   v2elmulpar_osp_sd                15499 non-null  float64
#  158   v2elmulpar_ord                   15499 non-null  float64
#  159   v2elmulpar_ord_codelow           15499 non-null  float64
#  160   v2elmulpar_ord_codehigh          15499 non-null  float64
#  161   v2elmulpar_mean                  4903 non-null   float64
#  162   v2elmulpar_nr                    4903 non-null   float64
#  163   v2elrgstry                       15540 non-null  float64
#  164   v2elrgstry_codelow               15540 non-null  float64
#  165   v2elrgstry_codehigh              15540 non-null  float64
#  166   v2elrgstry_sd                    15540 non-null  float64
#  167   v2elrgstry_osp                   15540 non-null  float64
#  168   v2elrgstry_osp_codelow           15540 non-null  float64
#  169   v2elrgstry_osp_codehigh          15540 non-null  float64
#  170   v2elrgstry_osp_sd                15540 non-null  float64
#  171   v2elrgstry_ord                   15540 non-null  float64
#  172   v2elrgstry_ord_codelow           15540 non-null  float64
#  173   v2elrgstry_ord_codehigh          15540 non-null  float64
#  174   v2elrgstry_mean                  4918 non-null   float64
#  175   v2elrgstry_nr                    4918 non-null   float64
#  176   v2elvotbuy                       15497 non-null  float64
#  177   v2elvotbuy_codelow               15497 non-null  float64
#  178   v2elvotbuy_codehigh              15497 non-null  float64
#  179   v2elvotbuy_sd                    15497 non-null  float64
#  180   v2elvotbuy_osp                   15497 non-null  float64
#  181   v2elvotbuy_osp_codelow           15497 non-null  float64
#  182   v2elvotbuy_osp_codehigh          15497 non-null  float64
#  183   v2elvotbuy_osp_sd                15497 non-null  float64
#  184   v2elvotbuy_ord                   15497 non-null  float64
#  185   v2elvotbuy_ord_codelow           15497 non-null  float64
#  186   v2elvotbuy_ord_codehigh          15497 non-null  float64
#  187   v2elvotbuy_mean                  4899 non-null   float64
#  188   v2elvotbuy_nr                    4899 non-null   float64
#  189   v2elirreg                        15495 non-null  float64
#  190   v2elirreg_codelow                15495 non-null  float64
#  191   v2elirreg_codehigh               15495 non-null  float64
#  192   v2elirreg_sd                     15495 non-null  float64
#  193   v2elirreg_osp                    15495 non-null  float64
#  194   v2elirreg_osp_codelow            15495 non-null  float64
#  195   v2elirreg_osp_codehigh           15495 non-null  float64
#  196   v2elirreg_osp_sd                 15495 non-null  float64
#  197   v2elirreg_ord                    15495 non-null  float64
#  198   v2elirreg_ord_codelow            15495 non-null  float64
#  199   v2elirreg_ord_codehigh           15495 non-null  float64
#  200   v2elirreg_mean                   4898 non-null   float64
#  201   v2elirreg_nr                     4898 non-null   float64
#  202   v2elintim                        15489 non-null  float64
#  203   v2elintim_codelow                15489 non-null  float64
#  204   v2elintim_codehigh               15489 non-null  float64
#  205   v2elintim_sd                     15489 non-null  float64
#  206   v2elintim_osp                    15489 non-null  float64
#  207   v2elintim_osp_codelow            15489 non-null  float64
#  208   v2elintim_osp_codehigh           15489 non-null  float64
#  209   v2elintim_osp_sd                 15489 non-null  float64
#  210   v2elintim_ord                    15489 non-null  float64
#  211   v2elintim_ord_codelow            15489 non-null  float64
#  212   v2elintim_ord_codehigh           15489 non-null  float64
#  213   v2elintim_mean                   4897 non-null   float64
#  214   v2elintim_nr                     4897 non-null   float64
#  215   v2elpeace                        15504 non-null  float64
#  216   v2elpeace_codelow                15504 non-null  float64
#  217   v2elpeace_codehigh               15504 non-null  float64
#  218   v2elpeace_sd                     15504 non-null  float64
#  219   v2elpeace_osp                    15504 non-null  float64
#  220   v2elpeace_osp_codelow            15504 non-null  float64
#  221   v2elpeace_osp_codehigh           15504 non-null  float64
#  222   v2elpeace_osp_sd                 15504 non-null  float64
#  223   v2elpeace_ord                    15504 non-null  float64
#  224   v2elpeace_ord_codelow            15504 non-null  float64
#  225   v2elpeace_ord_codehigh           15504 non-null  float64
#  226   v2elpeace_mean                   4884 non-null   float64
#  227   v2elpeace_nr                     4884 non-null   float64
#  228   v2elfrfair                       15498 non-null  float64
#  229   v2elfrfair_codelow               15498 non-null  float64
#  230   v2elfrfair_codehigh              15498 non-null  float64
#  231   v2elfrfair_sd                    15498 non-null  float64
#  232   v2elfrfair_osp                   15498 non-null  float64
#  233   v2elfrfair_osp_codelow           15498 non-null  float64
#  234   v2elfrfair_osp_codehigh          15498 non-null  float64
#  235   v2elfrfair_osp_sd                15498 non-null  float64
#  236   v2elfrfair_ord                   15498 non-null  float64
#  237   v2elfrfair_ord_codelow           15498 non-null  float64
#  238   v2elfrfair_ord_codehigh          15498 non-null  float64
#  239   v2elfrfair_mean                  4897 non-null   float64
#  240   v2elfrfair_nr                    4897 non-null   float64
#  241   v2elreggov                       27555 non-null  int64
#  242   v2elsrgel                        20331 non-null  float64
#  243   v2elrgpwr                        19105 non-null  float64
#  244   v2elrgpwr_codelow                19105 non-null  float64
#  245   v2elrgpwr_codehigh               19105 non-null  float64
#  246   v2elrgpwr_sd                     19105 non-null  float64
#  247   v2elrgpwr_osp                    19105 non-null  float64
#  248   v2elrgpwr_osp_codelow            19105 non-null  float64
#  249   v2elrgpwr_osp_codehigh           19105 non-null  float64
#  250   v2elrgpwr_osp_sd                 19105 non-null  float64
#  251   v2elrgpwr_ord                    19105 non-null  float64
#  252   v2elrgpwr_ord_codelow            19105 non-null  float64
#  253   v2elrgpwr_ord_codehigh           19105 non-null  float64
#  254   v2elrgpwr_mean                   24320 non-null  float64
#  255   v2elrgpwr_nr                     24320 non-null  float64
#  256   v2ellocgov                       27555 non-null  int64
#  257   v2ellocelc                       24421 non-null  float64
#  258   v2ellocpwr                       20230 non-null  float64
#  259   v2ellocpwr_codelow               20230 non-null  float64
#  260   v2ellocpwr_codehigh              20230 non-null  float64
#  261   v2ellocpwr_sd                    20230 non-null  float64
#  262   v2ellocpwr_osp                   20230 non-null  float64
#  263   v2ellocpwr_osp_codelow           20230 non-null  float64
#  264   v2ellocpwr_osp_codehigh          20230 non-null  float64
#  265   v2ellocpwr_osp_sd                20230 non-null  float64
#  266   v2ellocpwr_ord                   20230 non-null  float64
#  267   v2ellocpwr_ord_codelow           20230 non-null  float64
#  268   v2ellocpwr_ord_codehigh          20230 non-null  float64
#  269   v2ellocpwr_mean                  22314 non-null  float64
#  270   v2ellocpwr_nr                    22314 non-null  float64
#  271   v2psbars                         26885 non-null  float64
#  272   v2psbars_codelow                 26885 non-null  float64
#  273   v2psbars_codehigh                26885 non-null  float64
#  274   v2psbars_sd                      26885 non-null  float64
#  275   v2psbars_osp                     26885 non-null  float64
#  276   v2psbars_osp_codelow             26885 non-null  float64
#  277   v2psbars_osp_codehigh            26885 non-null  float64
#  278   v2psbars_osp_sd                  26885 non-null  float64
#  279   v2psbars_ord                     26885 non-null  float64
#  280   v2psbars_ord_codelow             26885 non-null  float64
#  281   v2psbars_ord_codehigh            26885 non-null  float64
#  282   v2psbars_mean                    26885 non-null  float64
#  283   v2psbars_nr                      26885 non-null  float64
#  284   v2psparban                       26823 non-null  float64
#  285   v2psparban_codelow               26823 non-null  float64
#  286   v2psparban_codehigh              26823 non-null  float64
#  287   v2psparban_sd                    26823 non-null  float64
#  288   v2psparban_osp                   26823 non-null  float64
#  289   v2psparban_osp_codelow           26823 non-null  float64
#  290   v2psparban_osp_codehigh          26823 non-null  float64
#  291   v2psparban_osp_sd                26823 non-null  float64
#  292   v2psparban_ord                   26823 non-null  float64
#  293   v2psparban_ord_codelow           26823 non-null  float64
#  294   v2psparban_ord_codehigh          26823 non-null  float64
#  295   v2psparban_mean                  26823 non-null  float64
#  296   v2psparban_nr                    26823 non-null  float64
#  297   v2psoppaut                       22917 non-null  float64
#  298   v2psoppaut_codelow               22917 non-null  float64
#  299   v2psoppaut_codehigh              22917 non-null  float64
#  300   v2psoppaut_sd                    22917 non-null  float64
#  301   v2psoppaut_osp                   22917 non-null  float64
#  302   v2psoppaut_osp_codelow           22917 non-null  float64
#  303   v2psoppaut_osp_codehigh          22917 non-null  float64
#  304   v2psoppaut_osp_sd                22917 non-null  float64
#  305   v2psoppaut_ord                   22917 non-null  float64
#  306   v2psoppaut_ord_codelow           22917 non-null  float64
#  307   v2psoppaut_ord_codehigh          22917 non-null  float64
#  308   v2psoppaut_mean                  22917 non-null  float64
#  309   v2psoppaut_nr                    22917 non-null  float64
#  310   v2psorgs                         26275 non-null  float64
#  311   v2psorgs_codelow                 26275 non-null  float64
#  312   v2psorgs_codehigh                26275 non-null  float64
#  313   v2psorgs_sd                      26275 non-null  float64
#  314   v2psorgs_osp                     26275 non-null  float64
#  315   v2psorgs_osp_codelow             26275 non-null  float64
#  316   v2psorgs_osp_codehigh            26275 non-null  float64
#  317   v2psorgs_osp_sd                  26275 non-null  float64
#  318   v2psorgs_ord                     26275 non-null  float64
#  319   v2psorgs_ord_codelow             26275 non-null  float64
#  320   v2psorgs_ord_codehigh            26275 non-null  float64
#  321   v2psorgs_mean                    26275 non-null  float64
#  322   v2psorgs_nr                      26275 non-null  float64
#  323   v2psprbrch                       26346 non-null  float64
#  324   v2psprbrch_codelow               26346 non-null  float64
#  325   v2psprbrch_codehigh              26346 non-null  float64
#  326   v2psprbrch_sd                    26346 non-null  float64
#  327   v2psprbrch_osp                   26346 non-null  float64
#  328   v2psprbrch_osp_codelow           26346 non-null  float64
#  329   v2psprbrch_osp_codehigh          26346 non-null  float64
#  330   v2psprbrch_osp_sd                26346 non-null  float64
#  331   v2psprbrch_ord                   26346 non-null  float64
#  332   v2psprbrch_ord_codelow           26346 non-null  float64
#  333   v2psprbrch_ord_codehigh          26346 non-null  float64
#  334   v2psprbrch_mean                  26346 non-null  float64
#  335   v2psprbrch_nr                    26346 non-null  float64
#  336   v2psprlnks                       25215 non-null  float64
#  337   v2psprlnks_codelow               25215 non-null  float64
#  338   v2psprlnks_codehigh              25215 non-null  float64
#  339   v2psprlnks_sd                    25215 non-null  float64
#  340   v2psprlnks_osp                   25215 non-null  float64
#  341   v2psprlnks_osp_codelow           25215 non-null  float64
#  342   v2psprlnks_osp_codehigh          25215 non-null  float64
#  343   v2psprlnks_osp_sd                25215 non-null  float64
#  344   v2psprlnks_ord                   25215 non-null  float64
#  345   v2psprlnks_ord_codelow           25215 non-null  float64
#  346   v2psprlnks_ord_codehigh          25215 non-null  float64
#  347   v2psprlnks_mean                  25215 non-null  float64
#  348   v2psprlnks_nr                    25215 non-null  float64
#  349   v2psplats                        25610 non-null  float64
#  350   v2psplats_codelow                25610 non-null  float64
#  351   v2psplats_codehigh               25610 non-null  float64
#  352   v2psplats_sd                     25610 non-null  float64
#  353   v2psplats_osp                    25610 non-null  float64
#  354   v2psplats_osp_codelow            25610 non-null  float64
#  355   v2psplats_osp_codehigh           25610 non-null  float64
#  356   v2psplats_osp_sd                 25610 non-null  float64
#  357   v2psplats_ord                    25610 non-null  float64
#  358   v2psplats_ord_codelow            25610 non-null  float64
#  359   v2psplats_ord_codehigh           25610 non-null  float64
#  360   v2psplats_mean                   25610 non-null  float64
#  361   v2psplats_nr                     25610 non-null  float64
#  362   v2pscnslnl                       24934 non-null  float64
#  363   v2pscnslnl_codelow               24934 non-null  float64
#  364   v2pscnslnl_codehigh              24934 non-null  float64
#  365   v2pscnslnl_sd                    24934 non-null  float64
#  366   v2pscnslnl_osp                   24934 non-null  float64
#  367   v2pscnslnl_osp_codelow           24934 non-null  float64
#  368   v2pscnslnl_osp_codehigh          24934 non-null  float64
#  369   v2pscnslnl_osp_sd                24934 non-null  float64
#  370   v2pscnslnl_ord                   24934 non-null  float64
#  371   v2pscnslnl_ord_codelow           24934 non-null  float64
#  372   v2pscnslnl_ord_codehigh          24934 non-null  float64
#  373   v2pscnslnl_mean                  24934 non-null  float64
#  374   v2pscnslnl_nr                    24934 non-null  float64
#  375   v2pscohesv                       24482 non-null  float64
#  376   v2pscohesv_codelow               24482 non-null  float64
#  377   v2pscohesv_codehigh              24482 non-null  float64
#  378   v2pscohesv_sd                    24482 non-null  float64
#  379   v2pscohesv_osp                   24482 non-null  float64
#  380   v2pscohesv_osp_codelow           24482 non-null  float64
#  381   v2pscohesv_osp_codehigh          24482 non-null  float64
#  382   v2pscohesv_osp_sd                24482 non-null  float64
#  383   v2pscohesv_ord                   24482 non-null  float64
#  384   v2pscohesv_ord_codelow           24482 non-null  float64
#  385   v2pscohesv_ord_codehigh          24482 non-null  float64
#  386   v2pscohesv_mean                  24482 non-null  float64
#  387   v2pscohesv_nr                    24482 non-null  float64
#  388   v2psnatpar                       19101 non-null  float64
#  389   v2psnatpar_codelow               19101 non-null  float64
#  390   v2psnatpar_codehigh              19101 non-null  float64
#  391   v2psnatpar_sd                    19101 non-null  float64
#  392   v2psnatpar_osp                   19101 non-null  float64
#  393   v2psnatpar_osp_codelow           19101 non-null  float64
#  394   v2psnatpar_osp_codehigh          19101 non-null  float64
#  395   v2psnatpar_osp_sd                19101 non-null  float64
#  396   v2psnatpar_ord                   19101 non-null  float64
#  397   v2psnatpar_ord_codelow           19101 non-null  float64
#  398   v2psnatpar_ord_codehigh          19101 non-null  float64
#  399   v2psnatpar_mean                  19101 non-null  float64
#  400   v2psnatpar_nr                    19101 non-null  float64
#  401   v2ddlexci                        19188 non-null  float64
#  402   v2ddsigpci                       1364 non-null   float64
#  403   v2ddsigdci                       872 non-null    float64
#  404   v2ddsiglci                       1097 non-null   float64
#  405   v2ddpartci                       1236 non-null   float64
#  406   v2ddapprci                       1312 non-null   float64
#  407   v2ddadmci                        1222 non-null   float64
#  408   v2ddspmci                        1222 non-null   float64
#  409   v2ddthreci                       19185 non-null  float64
#  410   v2ddlexrf                        19188 non-null  float64
#  411   v2ddsigprf                       1008 non-null   float64
#  412   v2ddsigdrf                       862 non-null    float64
#  413   v2ddpartrf                       1016 non-null   float64
#  414   v2ddapprrf                       970 non-null    float64
#  415   v2ddadmrf                        970 non-null    float64
#  416   v2ddspmrf                        970 non-null    float64
#  417   v2ddthrerf                       19185 non-null  float64
#  418   v2ddlexor                        19188 non-null  float64
#  419   v2ddpartor                       4741 non-null   float64
#  420   v2ddappor                        4742 non-null   float64
#  421   v2ddadmor                        4741 non-null   float64
#  422   v2ddspmor                        4738 non-null   float64
#  423   v2ddthreor                       19185 non-null  float64
#  424   v2ddlexpl                        19188 non-null  float64
#  425   v2ddpartpl                       5270 non-null   float64
#  426   v2ddapprpl                       5269 non-null   float64
#  427   v2ddadmpl                        5285 non-null   float64
#  428   v2ddspmpl                        5317 non-null   float64
#  429   v2ddthrepl                       19185 non-null  float64
#  430   v2ddyrci                         19178 non-null  float64
#  431   v2ddyrrf                         19178 non-null  float64
#  432   v2ddyror                         19178 non-null  float64
#  433   v2ddyrpl                         19178 non-null  float64
#  434   v2exdfcbhs                       26869 non-null  float64
#  435   v2exdfcbhs_codelow               26869 non-null  float64
#  436   v2exdfcbhs_codehigh              26869 non-null  float64
#  437   v2exdfcbhs_sd                    26869 non-null  float64
#  438   v2exdfcbhs_osp                   26869 non-null  float64
#  439   v2exdfcbhs_osp_codelow           26869 non-null  float64
#  440   v2exdfcbhs_osp_codehigh          26869 non-null  float64
#  441   v2exdfcbhs_osp_sd                26869 non-null  float64
#  442   v2exdfcbhs_ord                   26869 non-null  float64
#  443   v2exdfcbhs_ord_codelow           26869 non-null  float64
#  444   v2exdfcbhs_ord_codehigh          26869 non-null  float64
#  445   v2exdfcbhs_mean                  26869 non-null  float64
#  446   v2exdfcbhs_nr                    26869 non-null  float64
#  447   v2exdfdmhs                       26973 non-null  float64
#  448   v2exdfdmhs_codelow               26973 non-null  float64
#  449   v2exdfdmhs_codehigh              26973 non-null  float64
#  450   v2exdfdmhs_sd                    26973 non-null  float64
#  451   v2exdfdmhs_osp                   26973 non-null  float64
#  452   v2exdfdmhs_osp_codelow           26973 non-null  float64
#  453   v2exdfdmhs_osp_codehigh          26973 non-null  float64
#  454   v2exdfdmhs_osp_sd                26973 non-null  float64
#  455   v2exdfdmhs_ord                   26973 non-null  float64
#  456   v2exdfdmhs_ord_codelow           26973 non-null  float64
#  457   v2exdfdmhs_ord_codehigh          26973 non-null  float64
#  458   v2exdfdmhs_mean                  26973 non-null  float64
#  459   v2exdfdmhs_nr                    26973 non-null  float64
#  460   v2exhoshog                       27546 non-null  float64
#  461   v2exaphos                        17042 non-null  float64
#  462   v2ex_elechos                     27133 non-null  float64
#  463   v2expathhs                       27110 non-null  float64
#  464   v2exdfcbhs_rec                   26869 non-null  float64
#  465   v2exdfcbhs_rec_codelow           26869 non-null  float64
#  466   v2exdfcbhs_rec_codehigh          26869 non-null  float64
#  467   v2exdfcbhs_rec_sd                26869 non-null  float64
#  468   v2exdfcbhs_rec_osp               26869 non-null  float64
#  469   v2exdfcbhs_rec_osp_codelow       26869 non-null  float64
#  470   v2exdfcbhs_rec_osp_codehigh      26869 non-null  float64
#  471   v2exdfcbhs_rec_osp_sd            26869 non-null  float64
#  472   v2exdfcbhs_rec_ord               26869 non-null  float64
#  473   v2exdfcbhs_rec_ord_codelow       26869 non-null  float64
#  474   v2exdfcbhs_rec_ord_codehigh      26869 non-null  float64
#  475   v2exdfcbhs_rec_mean              26869 non-null  float64
#  476   v2exdfcbhs_rec_nr                26869 non-null  float64
#  477   v2exrmhsol_2                     27363 non-null  float64
#  478   v2exrmhsol_3                     27363 non-null  float64
#  479   v2exrmhsol_4                     27363 non-null  float64
#  480   v2exrmhsol_nr                    27363 non-null  float64
#  481   v2exremhog                       12691 non-null  float64
#  482   v2exremhog_codelow               12691 non-null  float64
#  483   v2exremhog_codehigh              12691 non-null  float64
#  484   v2exremhog_sd                    12691 non-null  float64
#  485   v2exremhog_osp                   12691 non-null  float64
#  486   v2exremhog_osp_codelow           12691 non-null  float64
#  487   v2exremhog_osp_codehigh          12691 non-null  float64
#  488   v2exremhog_osp_sd                12691 non-null  float64
#  489   v2exremhog_ord                   12691 non-null  float64
#  490   v2exremhog_ord_codelow           12691 non-null  float64
#  491   v2exremhog_ord_codehigh          12691 non-null  float64
#  492   v2exremhog_mean                  12691 non-null  float64
#  493   v2exremhog_nr                    12691 non-null  float64
#  494   v2exdjcbhg                       12974 non-null  float64
#  495   v2exdjcbhg_codelow               12974 non-null  float64
#  496   v2exdjcbhg_codehigh              12974 non-null  float64
#  497   v2exdjcbhg_sd                    12974 non-null  float64
#  498   v2exdjcbhg_osp                   12974 non-null  float64
#  499   v2exdjcbhg_osp_codelow           12974 non-null  float64
#  500   v2exdjcbhg_osp_codehigh          12974 non-null  float64
#  501   v2exdjcbhg_osp_sd                12974 non-null  float64
#  502   v2exdjcbhg_ord                   12974 non-null  float64
#  503   v2exdjcbhg_ord_codelow           12974 non-null  float64
#  504   v2exdjcbhg_ord_codehigh          12974 non-null  float64
#  505   v2exdjcbhg_mean                  12974 non-null  float64
#  506   v2exdjcbhg_nr                    12974 non-null  float64
#  507   v2exdfdshg                       12971 non-null  float64
#  508   v2exdfdshg_codelow               12971 non-null  float64
#  509   v2exdfdshg_codehigh              12971 non-null  float64
#  510   v2exdfdshg_sd                    12971 non-null  float64
#  511   v2exdfdshg_osp                   12971 non-null  float64
#  512   v2exdfdshg_osp_codelow           12971 non-null  float64
#  513   v2exdfdshg_osp_codehigh          12971 non-null  float64
#  514   v2exdfdshg_osp_sd                12971 non-null  float64
#  515   v2exdfdshg_ord                   12971 non-null  float64
#  516   v2exdfdshg_ord_codelow           12971 non-null  float64
#  517   v2exdfdshg_ord_codehigh          12971 non-null  float64
#  518   v2exdfdshg_mean                  12971 non-null  float64
#  519   v2exdfdshg_nr                    12971 non-null  float64
#  520   v2exaphogp                       11401 non-null  float64
#  521   v2ex_elechog                     13178 non-null  float64
#  522   v2ex_hogw                        26963 non-null  float64
#  523   v2expathhg                       13123 non-null  float64
#  524   v2exrmhgnp_2                     12963 non-null  float64
#  525   v2exrmhgnp_3                     12963 non-null  float64
#  526   v2exrmhgnp_4                     12963 non-null  float64
#  527   v2exrmhgnp_nr                    12963 non-null  float64
#  528   v2exrescon                       25985 non-null  float64
#  529   v2exrescon_codelow               25985 non-null  float64
#  530   v2exrescon_codehigh              25985 non-null  float64
#  531   v2exrescon_sd                    25985 non-null  float64
#  532   v2exrescon_osp                   25985 non-null  float64
#  533   v2exrescon_osp_codelow           25985 non-null  float64
#  534   v2exrescon_osp_codehigh          25985 non-null  float64
#  535   v2exrescon_osp_sd                25985 non-null  float64
#  536   v2exrescon_ord                   25985 non-null  float64
#  537   v2exrescon_ord_codelow           25985 non-null  float64
#  538   v2exrescon_ord_codehigh          25985 non-null  float64
#  539   v2exrescon_mean                  25985 non-null  float64
#  540   v2exrescon_nr                    25985 non-null  float64
#  541   v2exbribe                        26956 non-null  float64
#  542   v2exbribe_codelow                26956 non-null  float64
#  543   v2exbribe_codehigh               26956 non-null  float64
#  544   v2exbribe_sd                     26956 non-null  float64
#  545   v2exbribe_osp                    26956 non-null  float64
#  546   v2exbribe_osp_codelow            26956 non-null  float64
#  547   v2exbribe_osp_codehigh           26956 non-null  float64
#  548   v2exbribe_osp_sd                 26956 non-null  float64
#  549   v2exbribe_ord                    26956 non-null  float64
#  550   v2exbribe_ord_codelow            26956 non-null  float64
#  551   v2exbribe_ord_codehigh           26956 non-null  float64
#  552   v2exbribe_mean                   26956 non-null  float64
#  553   v2exbribe_nr                     26956 non-null  float64
#  554   v2exembez                        26859 non-null  float64
#  555   v2exembez_codelow                26859 non-null  float64
#  556   v2exembez_codehigh               26859 non-null  float64
#  557   v2exembez_sd                     26859 non-null  float64
#  558   v2exembez_osp                    26859 non-null  float64
#  559   v2exembez_osp_codelow            26859 non-null  float64
#  560   v2exembez_osp_codehigh           26859 non-null  float64
#  561   v2exembez_osp_sd                 26859 non-null  float64
#  562   v2exembez_ord                    26859 non-null  float64
#  563   v2exembez_ord_codelow            26859 non-null  float64
#  564   v2exembez_ord_codehigh           26859 non-null  float64
#  565   v2exembez_mean                   26859 non-null  float64
#  566   v2exembez_nr                     26859 non-null  float64
#  567   v2excrptps                       27097 non-null  float64
#  568   v2excrptps_codelow               27097 non-null  float64
#  569   v2excrptps_codehigh              27097 non-null  float64
#  570   v2excrptps_sd                    27097 non-null  float64
#  571   v2excrptps_osp                   27097 non-null  float64
#  572   v2excrptps_osp_codelow           27097 non-null  float64
#  573   v2excrptps_osp_codehigh          27097 non-null  float64
#  574   v2excrptps_osp_sd                27097 non-null  float64
#  575   v2excrptps_ord                   27097 non-null  float64
#  576   v2excrptps_ord_codelow           27097 non-null  float64
#  577   v2excrptps_ord_codehigh          27097 non-null  float64
#  578   v2excrptps_mean                  27097 non-null  float64
#  579   v2excrptps_nr                    27097 non-null  float64
#  580   v2exthftps                       27012 non-null  float64
#  581   v2exthftps_codelow               27012 non-null  float64
#  582   v2exthftps_codehigh              27012 non-null  float64
#  583   v2exthftps_sd                    27012 non-null  float64
#  584   v2exthftps_osp                   27012 non-null  float64
#  585   v2exthftps_osp_codelow           27012 non-null  float64
#  586   v2exthftps_osp_codehigh          27012 non-null  float64
#  587   v2exthftps_osp_sd                27012 non-null  float64
#  588   v2exthftps_ord                   27012 non-null  float64
#  589   v2exthftps_ord_codelow           27012 non-null  float64
#  590   v2exthftps_ord_codehigh          27012 non-null  float64
#  591   v2exthftps_mean                  27012 non-null  float64
#  592   v2exthftps_nr                    27012 non-null  float64
#  593   v2exapup                         3198 non-null   float64
#  594   v2exapupap                       3198 non-null   float64
#  595   v2lgbicam                        27527 non-null  float64
#  596   v2lgqstexp                       18085 non-null  float64
#  597   v2lgqstexp_codelow               18085 non-null  float64
#  598   v2lgqstexp_codehigh              18085 non-null  float64
#  599   v2lgqstexp_sd                    18085 non-null  float64
#  600   v2lgqstexp_osp                   18085 non-null  float64
#  601   v2lgqstexp_osp_codelow           18085 non-null  float64
#  602   v2lgqstexp_osp_codehigh          18085 non-null  float64
#  603   v2lgqstexp_osp_sd                18085 non-null  float64
#  604   v2lgqstexp_ord                   18085 non-null  float64
#  605   v2lgqstexp_ord_codelow           18085 non-null  float64
#  606   v2lgqstexp_ord_codehigh          18085 non-null  float64
#  607   v2lgqstexp_mean                  18085 non-null  float64
#  608   v2lgqstexp_nr                    18085 non-null  float64
#  609   v2lginvstp                       21329 non-null  float64
#  610   v2lginvstp_codelow               21329 non-null  float64
#  611   v2lginvstp_codehigh              21329 non-null  float64
#  612   v2lginvstp_sd                    21329 non-null  float64
#  613   v2lginvstp_osp                   21329 non-null  float64
#  614   v2lginvstp_osp_codelow           21329 non-null  float64
#  615   v2lginvstp_osp_codehigh          21329 non-null  float64
#  616   v2lginvstp_osp_sd                21329 non-null  float64
#  617   v2lginvstp_ord                   21329 non-null  float64
#  618   v2lginvstp_ord_codelow           21329 non-null  float64
#  619   v2lginvstp_ord_codehigh          21329 non-null  float64
#  620   v2lginvstp_mean                  21329 non-null  float64
#  621   v2lginvstp_nr                    21329 non-null  float64
#  622   v2lgotovst                       21654 non-null  float64
#  623   v2lgotovst_codelow               21654 non-null  float64
#  624   v2lgotovst_codehigh              21654 non-null  float64
#  625   v2lgotovst_sd                    21654 non-null  float64
#  626   v2lgotovst_osp                   21654 non-null  float64
#  627   v2lgotovst_osp_codelow           21654 non-null  float64
#  628   v2lgotovst_osp_codehigh          21654 non-null  float64
#  629   v2lgotovst_osp_sd                21654 non-null  float64
#  630   v2lgotovst_ord                   21654 non-null  float64
#  631   v2lgotovst_ord_codelow           21654 non-null  float64
#  632   v2lgotovst_ord_codehigh          21654 non-null  float64
#  633   v2lgotovst_mean                  21654 non-null  float64
#  634   v2lgotovst_nr                    21654 non-null  float64
#  635   v2lgcrrpt                        18131 non-null  float64
#  636   v2lgcrrpt_codelow                18131 non-null  float64
#  637   v2lgcrrpt_codehigh               18131 non-null  float64
#  638   v2lgcrrpt_sd                     18131 non-null  float64
#  639   v2lgcrrpt_osp                    18131 non-null  float64
#  640   v2lgcrrpt_osp_codelow            18131 non-null  float64
#  641   v2lgcrrpt_osp_codehigh           18131 non-null  float64
#  642   v2lgcrrpt_osp_sd                 18131 non-null  float64
#  643   v2lgcrrpt_ord                    18131 non-null  float64
#  644   v2lgcrrpt_ord_codelow            18131 non-null  float64
#  645   v2lgcrrpt_ord_codehigh           18131 non-null  float64
#  646   v2lgcrrpt_mean                   18131 non-null  float64
#  647   v2lgcrrpt_nr                     18131 non-null  float64
#  648   v2lgoppart                       17945 non-null  float64
#  649   v2lgoppart_codelow               17945 non-null  float64
#  650   v2lgoppart_codehigh              17945 non-null  float64
#  651   v2lgoppart_sd                    17945 non-null  float64
#  652   v2lgoppart_osp                   17945 non-null  float64
#  653   v2lgoppart_osp_codelow           17945 non-null  float64
#  654   v2lgoppart_osp_codehigh          17945 non-null  float64
#  655   v2lgoppart_osp_sd                17945 non-null  float64
#  656   v2lgoppart_ord                   17945 non-null  float64
#  657   v2lgoppart_ord_codelow           17945 non-null  float64
#  658   v2lgoppart_ord_codehigh          17945 non-null  float64
#  659   v2lgoppart_mean                  17945 non-null  float64
#  660   v2lgoppart_nr                    17945 non-null  float64
#  661   v2lgfunds                        18087 non-null  float64
#  662   v2lgfunds_codelow                18087 non-null  float64
#  663   v2lgfunds_codehigh               18087 non-null  float64
#  664   v2lgfunds_sd                     18087 non-null  float64
#  665   v2lgfunds_osp                    18087 non-null  float64
#  666   v2lgfunds_osp_codelow            18087 non-null  float64
#  667   v2lgfunds_osp_codehigh           18087 non-null  float64
#  668   v2lgfunds_osp_sd                 18087 non-null  float64
#  669   v2lgfunds_ord                    18087 non-null  float64
#  670   v2lgfunds_ord_codelow            18087 non-null  float64
#  671   v2lgfunds_ord_codehigh           18087 non-null  float64
#  672   v2lgfunds_mean                   18087 non-null  float64
#  673   v2lgfunds_nr                     18087 non-null  float64
#  674   v2ex_hosw                        26871 non-null  float64
#  675   v2ex_legconhos                   27555 non-null  int64
#  676   v2lgelecup                       8558 non-null   float64
#  677   v2lginelup                       8562 non-null   float64
#  678   v2lgello                         18262 non-null  float64
#  679   v2lgfemleg                       13685 non-null  float64
#  680   v2lginello                       18258 non-null  float64
#  681   v2dlreason                       19189 non-null  float64
#  682   v2dlreason_codelow               19189 non-null  float64
#  683   v2dlreason_codehigh              19189 non-null  float64
#  684   v2dlreason_sd                    19189 non-null  float64
#  685   v2dlreason_osp                   19189 non-null  float64
#  686   v2dlreason_osp_codelow           19189 non-null  float64
#  687   v2dlreason_osp_codehigh          19189 non-null  float64
#  688   v2dlreason_osp_sd                19189 non-null  float64
#  689   v2dlreason_ord                   19189 non-null  float64
#  690   v2dlreason_ord_codelow           19189 non-null  float64
#  691   v2dlreason_ord_codehigh          19189 non-null  float64
#  692   v2dlreason_mean                  19189 non-null  float64
#  693   v2dlreason_nr                    19189 non-null  float64
#  694   v2dlcommon                       19189 non-null  float64
#  695   v2dlcommon_codelow               19189 non-null  float64
#  696   v2dlcommon_codehigh              19189 non-null  float64
#  697   v2dlcommon_sd                    19189 non-null  float64
#  698   v2dlcommon_osp                   19189 non-null  float64
#  699   v2dlcommon_osp_codelow           19189 non-null  float64
#  700   v2dlcommon_osp_codehigh          19189 non-null  float64
#  701   v2dlcommon_osp_sd                19189 non-null  float64
#  702   v2dlcommon_ord                   19189 non-null  float64
#  703   v2dlcommon_ord_codelow           19189 non-null  float64
#  704   v2dlcommon_ord_codehigh          19189 non-null  float64
#  705   v2dlcommon_mean                  19189 non-null  float64
#  706   v2dlcommon_nr                    19189 non-null  float64
#  707   v2dlcountr                       19189 non-null  float64
#  708   v2dlcountr_codelow               19189 non-null  float64
#  709   v2dlcountr_codehigh              19189 non-null  float64
#  710   v2dlcountr_sd                    19189 non-null  float64
#  711   v2dlcountr_osp                   19189 non-null  float64
#  712   v2dlcountr_osp_codelow           19189 non-null  float64
#  713   v2dlcountr_osp_codehigh          19189 non-null  float64
#  714   v2dlcountr_osp_sd                19189 non-null  float64
#  715   v2dlcountr_ord                   19189 non-null  float64
#  716   v2dlcountr_ord_codelow           19189 non-null  float64
#  717   v2dlcountr_ord_codehigh          19189 non-null  float64
#  718   v2dlcountr_mean                  19189 non-null  float64
#  719   v2dlcountr_nr                    19189 non-null  float64
#  720   v2dlconslt                       27266 non-null  float64
#  721   v2dlconslt_codelow               27266 non-null  float64
#  722   v2dlconslt_codehigh              27266 non-null  float64
#  723   v2dlconslt_sd                    27266 non-null  float64
#  724   v2dlconslt_osp                   27266 non-null  float64
#  725   v2dlconslt_osp_codelow           27266 non-null  float64
#  726   v2dlconslt_osp_codehigh          27266 non-null  float64
#  727   v2dlconslt_osp_sd                27266 non-null  float64
#  728   v2dlconslt_ord                   27266 non-null  float64
#  729   v2dlconslt_ord_codelow           27266 non-null  float64
#  730   v2dlconslt_ord_codehigh          27266 non-null  float64
#  731   v2dlconslt_mean                  27266 non-null  float64
#  732   v2dlconslt_nr                    27266 non-null  float64
#  733   v2dlengage                       27268 non-null  float64
#  734   v2dlengage_codelow               27268 non-null  float64
#  735   v2dlengage_codehigh              27268 non-null  float64
#  736   v2dlengage_sd                    27268 non-null  float64
#  737   v2dlengage_osp                   27268 non-null  float64
#  738   v2dlengage_osp_codelow           27268 non-null  float64
#  739   v2dlengage_osp_codehigh          27268 non-null  float64
#  740   v2dlengage_osp_sd                27268 non-null  float64
#  741   v2dlengage_ord                   27268 non-null  float64
#  742   v2dlengage_ord_codelow           27268 non-null  float64
#  743   v2dlengage_ord_codehigh          27268 non-null  float64
#  744   v2dlengage_mean                  27268 non-null  float64
#  745   v2dlengage_nr                    27268 non-null  float64
# ...
#  1570  v2peasjsoc_osp_codehigh          18710 non-null  float64
#  1571  v2peasjsoc_osp_sd                18710 non-null  float64
#  1572  v2peasjsoc_ord                   18710 non-null  float64
#  1573  v2peasjsoc_ord_codelow           18710 non-null  float64
#  1574  v2peasjsoc_ord_codehigh          18710 non-null  float64
#  1575  v2peasjsoc_mean                  18951 non-null  float64
#  1576  v2peasjsoc_nr                    18951 non-null  float64
#  1577  v2peasbsoc                       18710 non-null  float64
#  1578  v2peasbsoc_codelow               18710 non-null  float64
#  1579  v2peasbsoc_codehigh              18710 non-null  float64
#  1580  v2peasbsoc_sd                    18710 non-null  float64
#  1581  v2peasbsoc_osp                   18710 non-null  float64
#  1582  v2peasbsoc_osp_codelow           18710 non-null  float64
#  1583  v2peasbsoc_osp_codehigh          18710 non-null  float64
#  1584  v2peasbsoc_osp_sd                18710 non-null  float64
#  1585  v2peasbsoc_ord                   18710 non-null  float64
#  1586  v2peasbsoc_ord_codelow           18710 non-null  float64
#  1587  v2peasbsoc_ord_codehigh          18710 non-null  float64
#  1588  v2peasbsoc_mean                  18951 non-null  float64
#  1589  v2peasbsoc_nr                    18951 non-null  float64
#  1590  v2cafres                         14706 non-null  float64
#  1591  v2cafres_codelow                 14706 non-null  float64
#  1592  v2cafres_codehigh                14706 non-null  float64
#  1593  v2cafres_sd                      14706 non-null  float64
#  1594  v2cafres_osp                     14706 non-null  float64
#  1595  v2cafres_osp_codelow             14706 non-null  float64
#  1596  v2cafres_osp_codehigh            14706 non-null  float64
#  1597  v2cafres_osp_sd                  14706 non-null  float64
#  1598  v2cafres_ord                     14706 non-null  float64
#  1599  v2cafres_ord_codelow             14706 non-null  float64
#  1600  v2cafres_ord_codehigh            14706 non-null  float64
#  1601  v2cafres_mean                    14976 non-null  float64
#  1602  v2cafres_nr                      14976 non-null  float64
#  1603  v2cafexch                        14698 non-null  float64
#  1604  v2cafexch_codelow                14698 non-null  float64
#  1605  v2cafexch_codehigh               14698 non-null  float64
#  1606  v2cafexch_sd                     14698 non-null  float64
#  1607  v2cafexch_osp                    14698 non-null  float64
#  1608  v2cafexch_osp_codelow            14698 non-null  float64
#  1609  v2cafexch_osp_codehigh           14698 non-null  float64
#  1610  v2cafexch_osp_sd                 14698 non-null  float64
#  1611  v2cafexch_ord                    14698 non-null  float64
#  1612  v2cafexch_ord_codelow            14698 non-null  float64
#  1613  v2cafexch_ord_codehigh           14698 non-null  float64
#  1614  v2cafexch_mean                   14976 non-null  float64
#  1615  v2cafexch_nr                     14976 non-null  float64
#  1616  v2cainsaut                       14687 non-null  float64
#  1617  v2cainsaut_codelow               14687 non-null  float64
#  1618  v2cainsaut_codehigh              14687 non-null  float64
#  1619  v2cainsaut_sd                    14687 non-null  float64
#  1620  v2cainsaut_osp                   14687 non-null  float64
#  1621  v2cainsaut_osp_codelow           14687 non-null  float64
#  1622  v2cainsaut_osp_codehigh          14687 non-null  float64
#  1623  v2cainsaut_osp_sd                14687 non-null  float64
#  1624  v2cainsaut_ord                   14687 non-null  float64
#  1625  v2cainsaut_ord_codelow           14687 non-null  float64
#  1626  v2cainsaut_ord_codehigh          14687 non-null  float64
#  1627  v2cainsaut_mean                  14955 non-null  float64
#  1628  v2cainsaut_nr                    14955 non-null  float64
#  1629  v2casurv                         14690 non-null  float64
#  1630  v2casurv_codelow                 14690 non-null  float64
#  1631  v2casurv_codehigh                14690 non-null  float64
#  1632  v2casurv_sd                      14690 non-null  float64
#  1633  v2casurv_osp                     14690 non-null  float64
#  1634  v2casurv_osp_codelow             14690 non-null  float64
#  1635  v2casurv_osp_codehigh            14690 non-null  float64
#  1636  v2casurv_osp_sd                  14690 non-null  float64
#  1637  v2casurv_ord                     14690 non-null  float64
#  1638  v2casurv_ord_codelow             14690 non-null  float64
#  1639  v2casurv_ord_codehigh            14690 non-null  float64
#  1640  v2casurv_mean                    14955 non-null  float64
#  1641  v2casurv_nr                      14955 non-null  float64
#  1642  v2x_regime                       19222 non-null  float64
#  1643  v2x_regime_amb                   19222 non-null  float64
#  1644  v2x_accountability               19183 non-null  float64
#  1645  v2x_accountability_codelow       19183 non-null  float64
#  1646  v2x_accountability_codehigh      19183 non-null  float64
#  1647  v2x_accountability_osp           19183 non-null  float64
#  1648  v2x_accountability_osp_codelow   19183 non-null  float64
#  1649  v2x_accountability_osp_codehigh  19183 non-null  float64
#  1650  v2x_veracc                       19183 non-null  float64
#  1651  v2x_veracc_codelow               19183 non-null  float64
#  1652  v2x_veracc_codehigh              19183 non-null  float64
#  1653  v2x_veracc_osp                   19183 non-null  float64
#  1654  v2x_veracc_osp_codelow           19183 non-null  float64
#  1655  v2x_veracc_osp_codehigh          19183 non-null  float64
#  1656  v2x_diagacc                      19183 non-null  float64
#  1657  v2x_diagacc_codelow              19183 non-null  float64
#  1658  v2x_diagacc_codehigh             19183 non-null  float64
#  1659  v2x_diagacc_osp                  19183 non-null  float64
#  1660  v2x_diagacc_osp_codelow          19183 non-null  float64
#  1661  v2x_diagacc_osp_codehigh         19183 non-null  float64
#  1662  v2x_horacc                       19183 non-null  float64
#  1663  v2x_horacc_codelow               19183 non-null  float64
#  1664  v2x_horacc_codehigh              19183 non-null  float64
#  1665  v2x_horacc_osp                   19183 non-null  float64
#  1666  v2x_horacc_osp_codelow           19183 non-null  float64
#  1667  v2x_horacc_osp_codehigh          19183 non-null  float64
#  1668  v2x_ex_confidence                27077 non-null  float64
#  1669  v2x_ex_direlect                  26542 non-null  float64
#  1670  v2x_ex_hereditary                27391 non-null  float64
#  1671  v2x_ex_military                  27391 non-null  float64
#  1672  v2x_ex_party                     27391 non-null  float64
#  1673  v2x_neopat                       26009 non-null  float64
#  1674  v2x_neopat_codelow               26009 non-null  float64
#  1675  v2x_neopat_codehigh              26009 non-null  float64
#  1676  v2x_neopat_sd                    26009 non-null  float64
#  1677  v2xnp_client                     25316 non-null  float64
#  1678  v2xnp_client_codelow             25316 non-null  float64
#  1679  v2xnp_client_codehigh            25316 non-null  float64
#  1680  v2xnp_client_sd                  25316 non-null  float64
#  1681  v2xnp_pres                       26588 non-null  float64
#  1682  v2xnp_pres_codelow               26588 non-null  float64
#  1683  v2xnp_pres_codehigh              26588 non-null  float64
#  1684  v2xnp_pres_sd                    26588 non-null  float64
#  1685  v2xnp_regcorr                    27051 non-null  float64
#  1686  v2xnp_regcorr_codelow            27051 non-null  float64
#  1687  v2xnp_regcorr_codehigh           27051 non-null  float64
#  1688  v2xnp_regcorr_sd                 27051 non-null  float64
#  1689  v2x_civlib                       27124 non-null  float64
#  1690  v2x_civlib_codelow               27124 non-null  float64
#  1691  v2x_civlib_codehigh              27124 non-null  float64
#  1692  v2x_civlib_sd                    27124 non-null  float64
#  1693  v2x_clphy                        27432 non-null  float64
#  1694  v2x_clphy_codelow                27432 non-null  float64
#  1695  v2x_clphy_codehigh               27432 non-null  float64
#  1696  v2x_clphy_sd                     27432 non-null  float64
#  1697  v2x_clpol                        27214 non-null  float64
#  1698  v2x_clpol_codelow                27214 non-null  float64
#  1699  v2x_clpol_codehigh               27214 non-null  float64
#  1700  v2x_clpol_sd                     27214 non-null  float64
#  1701  v2x_clpriv                       27438 non-null  float64
#  1702  v2x_clpriv_codelow               27438 non-null  float64
#  1703  v2x_clpriv_codehigh              27438 non-null  float64
#  1704  v2x_clpriv_sd                    27438 non-null  float64
#  1705  v2xpe_exlecon                    18735 non-null  float64
#  1706  v2xpe_exlecon_codelow            18735 non-null  float64
#  1707  v2xpe_exlecon_codehigh           18735 non-null  float64
#  1708  v2xpe_exlecon_sd                 18735 non-null  float64
#  1709  v2xpe_exlgender                  18751 non-null  float64
#  1710  v2xpe_exlgender_codelow          18751 non-null  float64
#  1711  v2xpe_exlgender_codehigh         18751 non-null  float64
#  1712  v2xpe_exlgender_sd               18751 non-null  float64
#  1713  v2xpe_exlgeo                     18736 non-null  float64
#  1714  v2xpe_exlgeo_codelow             18736 non-null  float64
#  1715  v2xpe_exlgeo_codehigh            18736 non-null  float64
#  1716  v2xpe_exlgeo_sd                  18736 non-null  float64
#  1717  v2xpe_exlpol                     18700 non-null  float64
#  1718  v2xpe_exlpol_codelow             18700 non-null  float64
#  1719  v2xpe_exlpol_codehigh            18700 non-null  float64
#  1720  v2xpe_exlpol_sd                  18700 non-null  float64
#  1721  v2xpe_exlsocgr                   18736 non-null  float64
#  1722  v2xpe_exlsocgr_codelow           18736 non-null  float64
#  1723  v2xpe_exlsocgr_codehigh          18736 non-null  float64
#  1724  v2xpe_exlsocgr_sd                18736 non-null  float64
#  1725  v2x_corr                         26664 non-null  float64
#  1726  v2x_corr_codelow                 26664 non-null  float64
#  1727  v2x_corr_codehigh                26664 non-null  float64
#  1728  v2x_corr_sd                      26664 non-null  float64
#  1729  v2x_execorr                      26859 non-null  float64
#  1730  v2x_execorr_codelow              26859 non-null  float64
#  1731  v2x_execorr_codehigh             26859 non-null  float64
#  1732  v2x_execorr_sd                   26859 non-null  float64
#  1733  v2x_pubcorr                      27013 non-null  float64
#  1734  v2x_pubcorr_codelow              27013 non-null  float64
#  1735  v2x_pubcorr_codehigh             27013 non-null  float64
#  1736  v2x_pubcorr_sd                   27013 non-null  float64
#  1737  v2x_gender                       22600 non-null  float64
#  1738  v2x_gender_codelow               22600 non-null  float64
#  1739  v2x_gender_codehigh              22600 non-null  float64
#  1740  v2x_gender_sd                    22600 non-null  float64
#  1741  v2x_gencl                        27359 non-null  float64
#  1742  v2x_gencl_codelow                27359 non-null  float64
#  1743  v2x_gencl_codehigh               27359 non-null  float64
#  1744  v2x_gencl_sd                     27359 non-null  float64
#  1745  v2x_gencs                        26927 non-null  float64
#  1746  v2x_gencs_codelow                26927 non-null  float64
#  1747  v2x_gencs_codehigh               26927 non-null  float64
#  1748  v2x_gencs_sd                     26927 non-null  float64
#  1749  v2x_genpp                        22946 non-null  float64
#  1750  v2x_genpp_codelow                22946 non-null  float64
#  1751  v2x_genpp_codehigh               22946 non-null  float64
#  1752  v2x_genpp_sd                     22946 non-null  float64
#  1753  v2x_rule                         27168 non-null  float64
#  1754  v2x_rule_codelow                 27168 non-null  float64
#  1755  v2x_rule_codehigh                27168 non-null  float64
#  1756  v2x_rule_sd                      27168 non-null  float64
#  1757  v2xcl_acjst                      27348 non-null  float64
#  1758  v2xcl_acjst_codelow              27348 non-null  float64
#  1759  v2xcl_acjst_codehigh             27348 non-null  float64
#  1760  v2xcl_acjst_sd                   27348 non-null  float64
#  1761  v2xcl_prpty                      27358 non-null  float64
#  1762  v2xcl_prpty_codelow              27358 non-null  float64
#  1763  v2xcl_prpty_codehigh             27358 non-null  float64
#  1764  v2xcl_prpty_sd                   27358 non-null  float64
#  1765  v2xdd_i_ci                       19184 non-null  float64
#  1766  v2xdd_i_rf                       19184 non-null  float64
#  1767  v2xdd_i_or                       19184 non-null  float64
#  1768  v2xdd_i_pl                       19184 non-null  float64
#  1769  v2xdd_cic                        19189 non-null  float64
#  1770  v2xdd_toc                        19189 non-null  float64
#  1771  v2xcs_ccsi                       27158 non-null  float64
#  1772  v2xcs_ccsi_codelow               27158 non-null  float64
#  1773  v2xcs_ccsi_codehigh              27158 non-null  float64
#  1774  v2xcs_ccsi_sd                    27158 non-null  float64
#  1775  v2x_elecreg                      27546 non-null  float64
#  1776  v2xex_elecreg                    27546 non-null  float64
#  1777  v2xlg_elecreg                    27546 non-null  float64
#  1778  v2x_EDcomp_thick                 26449 non-null  float64
#  1779  v2x_EDcomp_thick_codelow         26449 non-null  float64
#  1780  v2x_EDcomp_thick_codehigh        26449 non-null  float64
#  1781  v2x_EDcomp_thick_sd              26449 non-null  float64
#  1782  v2x_freexp                       27068 non-null  float64
#  1783  v2x_freexp_codelow               27068 non-null  float64
#  1784  v2x_freexp_codehigh              27068 non-null  float64
#  1785  v2x_freexp_sd                    27068 non-null  float64
#  1786  v2x_hosabort                     27133 non-null  float64
#  1787  v2x_hosinter                     27133 non-null  float64
#  1788  v2x_legabort                     27133 non-null  float64
#  1789  v2xcl_disc                       27514 non-null  float64
#  1790  v2xcl_disc_codelow               27514 non-null  float64
#  1791  v2xcl_disc_codehigh              27514 non-null  float64
#  1792  v2xcl_disc_sd                    27514 non-null  float64
#  1793  v2xcl_dmove                      27436 non-null  float64
#  1794  v2xcl_dmove_codelow              27436 non-null  float64
#  1795  v2xcl_dmove_codehigh             27436 non-null  float64
#  1796  v2xcl_dmove_sd                   27436 non-null  float64
#  1797  v2xcl_slave                      27352 non-null  float64
#  1798  v2xcl_slave_codelow              27352 non-null  float64
#  1799  v2xcl_slave_codehigh             27352 non-null  float64
#  1800  v2xcl_slave_sd                   27352 non-null  float64
#  1801  v2xel_elecparl                   27555 non-null  int64
#  1802  v2xel_elecpres                   27555 non-null  int64
#  1803  v2xex_elecleg                    27404 non-null  float64
#  1804  v2xlg_leginter                   27555 non-null  int64
#  1805  v2xme_altinf                     26995 non-null  float64
#  1806  v2xme_altinf_codelow             26995 non-null  float64
#  1807  v2xme_altinf_codehigh            26995 non-null  float64
#  1808  v2xme_altinf_sd                  26995 non-null  float64
#  1809  v2xps_party                      17630 non-null  float64
#  1810  v2xps_party_codelow              17630 non-null  float64
#  1811  v2xps_party_codehigh             17630 non-null  float64
#  1812  v2x_divparctrl                   19101 non-null  float64
#  1813  v2x_feduni                       27488 non-null  float64
#  1814  v2xca_academ                     14976 non-null  float64
#  1815  v2xca_academ_codelow             14976 non-null  float64
#  1816  v2xca_academ_codehigh            14976 non-null  float64
#  1817  v2xca_academ_sd                  14976 non-null  float64
# dtypes: float64(1801), int64(13), object(4)
# memory usage: 382.2+ MB

# %% [raw]
#  0     country_name                     27555 non-null  object
#  1     country_text_id                  27555 non-null  object
#  2     country_id                       27555 non-null  int64
#  3     year                             27555 non-null  int64
#
#
#  22    v2x_polyarchy                    26273 non-null  float64
#  23    v2x_polyarchy_codelow            26273 non-null  float64
#  24    v2x_polyarchy_codehigh           26273 non-null  float64
#  25    v2x_polyarchy_sd                 26273 non-null  float64
#  26    v2x_libdem                       25134 non-null  float64
#  27    v2x_libdem_codelow               25134 non-null  float64
#  28    v2x_libdem_codehigh              25134 non-null  float64
#  29    v2x_libdem_sd                    25134 non-null  float64
#  30    v2x_partipdem                    25661 non-null  float64
#  31    v2x_partipdem_codelow            25661 non-null  float64
#  32    v2x_partipdem_codehigh           25661 non-null  float64
#  33    v2x_partipdem_sd                 25661 non-null  float64
#  34    v2x_delibdem                     19129 non-null  float64
#  35    v2x_delibdem_codelow             19129 non-null  float64
#  36    v2x_delibdem_codehigh            19129 non-null  float64
#  37    v2x_delibdem_sd                  19129 non-null  float64
#  38    v2x_egaldem                      19130 non-null  float64
#  39    v2x_egaldem_codelow              19130 non-null  float64
#  40    v2x_egaldem_codehigh             19130 non-null  float64
#  41    v2x_egaldem_sd                   19130 non-null  float64
#
#  1642  v2x_regime                       19222 non-null  float64
#  1643  v2x_regime_amb                   19222 non-null  float64

# %%
# building a small variable descriptor dictionary, based on the information from the codebook
variable_descriptions_list=[{'indicator':'v2x_libdem',
                             'question':['To what extent is the ideal of liberal democracy achieved?'],
                             'clarification':['The liberal principle of democracy emphasizes the importance of protecting individual and minority rights against the tyranny of the state and the tyranny of the majority.', 'The liberal model takes a "negative" view of political power insofar as it judges the quality of democracy bythe limits placed on government.','This is achieved by constitutionally protected civil liberties,strong rule of law, an independent judiciary, and effective checks and balances that, together,limit the exercise of executive power.','To make this a measure of liberal democracy, the index also takes the level of electoral democracy into account.']},
                            
                            {'indicator':'v2x_regime',
                             'question':['How can the political regime overall be classified considering the competitiveness of access to power (polyarchy) as well as liberal principles?'], 
                             'clarification':["0: Closed autocracy: No multiparty elections for the chief executive or the legislature.","1: Electoral autocracy: De-jure multiparty elections for the chief executive and the legislature, but failing to achieve that elections are free and fair, or de-facto multiparty, or a minimum level of Dahl’s institutional prerequisites of polyarchy as measured by V-Dem’s Electoral Democracy Index (v2x_polyarchy)."," 2: Electoral democracy: De-facto free and fair multiparty elections and a minimum level of Dahl’s institutional prerequisites for polyarchy as measured by V- Dem’s Electoral Democracy Index (v2x_polyarchy), but either access to justice, or transparent law enforcement, or liberal principles of respect for personal liberties, rule of law, and judicial as well as legislative constraints on the executive not satisfied as measured by V-Dem’s Liberal Component Index (v2x_liberal).","3: Liberal democracy: De-facto free and fair multiparty elections and a minimum level of Dahl’s institutional prerequisites for polyarchy as measured by V- Dem’s Electoral Democracy Index (v2x_polyarchy) are guaranteed as well as access to justice, transparent law enforcement and the liberal principles of respect for personal liberties, rule of law, and judicial as well as legislative constraints on the executive satisfied as measured by V-Dem’s Liberal Component Index (v2x_liberal)."]},
                           ]
variable_df=pd.DataFrame(variable_descriptions_list)

# %%
# in order to filter the dataset by region, reading in an additional dataset to later merge with existing one
regions = pd.read_csv('../data/data_raw/VDEM-adjusted_country-and-continent-codes-list.csv', delimiter=';', usecols=['continent','region','subregion','M49 code', 'ISO-alpha3 code'])
regions.head()
# Out:
#   continent            region         subregion  M49 code ISO-alpha3 code
# 0      Asia     Southern Asia     Southern Asia       4.0             AFG
# 1    Europe   Southern Europe   Southern Europe       8.0             ALB
# 2  Americas  Northern America  Northern America      10.0             ATA
# 3    Africa   Northern Africa   Northern Africa      12.0             DZA
# 4   Oceania         Polynesia         Polynesia      16.0             ASM

# %%
#number of countries before merge
len(dfr.country_text_id.unique())
# Out:
# 179

# %%
# merging the two datasets
dfrr=dfr.merge(regions,left_on='country_text_id', right_on='ISO-alpha3 code')

# %%
#number of countries after merge
len(dfrr.country_text_id.unique())
# Out:
# 179

# %%
#print codes for those that are missing after merge
for country in dfr.country_text_id.unique():
    if country in dfrr.country_text_id.unique():
        pass
    else:
        print(country)

# %%
# formatting the year information into datetime for correct display in chart
dfrr['year_formatted']=pd.to_datetime(dfrr['year'],format='%Y')

# %%
# adding a new column that converts numeric regime classification into verbal classification
dfrr['v2x_regime_text']= np.where(dfrr['v2x_regime'] == 0, 'Closed autocracy', (np.where(dfrr['v2x_regime'] == 1, 'Electoral autocracy',(np.where(dfrr['v2x_regime'] == 2, 'Electoral democracy',(np.where(dfrr['v2x_regime'] == 3, 'Liberal democracy', 'sth went wrong')))))))

# %%
#defining a function to display a chart by continent and for the selected indicator
def chart_index_line(selected_continent,selected_index):
    
    #reduce dataframe to only include data for selected continent and the columns that are needed for display
    df_reduced = dfrr[dfrr['continent']==selected_continent][['country_name','year_formatted','v2x_regime','v2x_regime_text',selected_index]]
    
    #creating the chart from the reduced dataframe
    charted_index = alt.Chart(df_reduced).mark_circle(size=30, opacity=1).encode(
        
        # coloring by regime type
        alt.Color('v2x_regime_text:O',
                  # assigning a color per regime type
                    scale = alt.Scale(domain=['Closed autocracy','Electoral autocracy','Electoral democracy','Liberal democracy'], 
                                      range=['#BE232D','#EE8C0A','#00A5FF','#002D5A']),
                  # refining the displayed legend
                    legend=alt.Legend(values=['Liberal democracy','Electoral democracy','Electoral autocracy','Closed autocracy'], title='Classification of regime'),
                ), 
       
        alt.Y(selected_index, # on the y-axis, display the selected indicator
              scale=alt.Scale(domain=[0, 1]), # set y-scale to range from 0 to 1
              axis=alt.Axis(title=' ') # display no axis title
             ),
        
        alt.X('year_formatted:T', # on the x-axis, display the year
             axis=alt.Axis(title='  ') # display no axis title
             ),
        
        tooltip=['year_formatted', selected_index], # creating a tooltip for inspection
        
        facet=alt.Facet('country_name', # make one chart per country
                        columns=3, # arrange small multiple with 3 columns
                        sort=alt.EncodingSortField(selected_index, # sort them based on the selected indicator
                                                   op='mean', # create an average (mean) over all values for that country
                                                   order='descending')), # sort the charts based on the mean in descending order
    ).properties(
        width=140, #define chart width
        height=70, #define chart height
        title={
            # use the dict created earlier for title and subhead information
            'text':variable_df[variable_df['indicator']==selected_index]['question'].item(), 
            'fontSize':24,
            'subtitle':variable_df[variable_df['indicator']==selected_index]['clarification'].item(),
        })
    
    return charted_index.display()

# %%
chart_index_line('Europe','v2x_libdem')
# Out:
# alt.Chart(...)

# %%
chart_index_line('Asia','v2x_libdem')
# Out:
# alt.Chart(...)

# %%
chart_index_line('Africa','v2x_libdem')
# Out:
# alt.Chart(...)

# %%
chart_index_line('Americas','v2x_libdem')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Map

# %%
# Extracting the data for 2022 to use in mapping software
dfrr[dfrr['year']==dfrr.year.max()][['ISO-alpha3 code', 'country_name','v2x_libdem','v2x_regime_text']].to_csv('data-export_libdem_index_2022.csv', index = False)
